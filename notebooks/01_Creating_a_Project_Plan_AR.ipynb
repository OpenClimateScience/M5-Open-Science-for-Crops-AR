# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h1 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <span dir="ltr" style="unicode-bidi: isolate;">M5.1</span> – إنشاء خطة المشروع
# </h1>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# جزء من:
# <a href="https://github.com/OpenClimateScience/M5-Open-Science-for-Crops" dir="ltr">
# علوم المناخ المفتوحة للمحاصيل وظروفها
# </a>
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# مقدمة
# </h2>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# في هذه الوحدة سنتعلّم كيفية إنشاء برمجيات بحثية يمكن تثبيتها وتشغيلها بسهولة على حاسوب شخص آخر، بما يتيح له إعادة إنتاج نتائجنا العلمية. لقد اطّلعنا على طريقتين أخريين لتحقيق ذلك في الوحدتين
# <span dir="ltr" style="unicode-bidi: isolate;">3</span>
# و<span dir="ltr" style="unicode-bidi: isolate;">4</span>.
# وناقشنا أنه لضمان إعادة إنتاج نتائج أي مشروع حاسوبي:
# </p>
#
# <ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# يجب أن تكون <strong>بيئة البرمجيات</strong> متطابقة،
# </li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# ويجب أن تكون <strong>إصدارات الحزم</strong> المثبّتة متطابقة،
# </li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# ويجب تشغيل <strong>الشيفرة نفسها</strong> على <strong>البيانات نفسها</strong>.
# </li>
# </ul>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# يعتمد الوصول إلى الشيفرة والبيانات التي استُخدمت لإنتاج نتيجة علمية على مدى التزام الباحث بمبادئ العلم المفتوح. ينبغي مشاركة الشيفرة والبيانات في مستودعات تملك مُعرّفًا فريدًا ودائمًا (مثل
# <span dir="ltr" style="unicode-bidi: isolate;">DOI</span>)،
# مع إرفاق رخصة مفتوحة تتيح إعادة الاستخدام.
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# إدارة سير العمل
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# كيف نضمن إعداد <strong>بيئة البرمجيات</strong> بالطريقة نفسها؟ نستخدم مدير بيئات لإنشاء بيئة افتراضية، أي تثبيت
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>
# مخصّص للمشروع. ثم نستخدم <strong>مدير الحزم</strong> لتبسيط عملية تثبيت الحزم والتحقق من إصدار كل حزمة.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# في هذا الدرس سنضيف بُعدًا ثالثًا لمشاريع البرمجيات العلمية القابلة لإعادة الإنتاج: إدارة سير العمل.
# </strong>
# نظرًا لأن معالجة البيانات قد تتضمن عددًا كبيرًا من الخطوات وبيانات ضخمة، فإننا نهدف إلى جعل إعادة إنتاج النتائج سهلة قدر الإمكان. ومن المثالي أن يتمكن المستخدم من تشغيل ملف تنفيذي (على سبيل المثال «نقرة مزدوجة») ينفّذ جميع الخطوات تلقائيًا، بدءًا من تنزيل البيانات وحتى إنتاج الشكل النهائي. أدوات إدارة سير العمل تُمكّننا من الاقتراب من هذا الهدف. وإذا قارنا بين أدوات إدارة البيئة، وإدارة الحزم، وإدارة سير العمل التي استعرضناها في كل وحدة حتى الآن، فيمكننا إنشاء جدول للمقارنة بينها.
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# تخطيط مشروعنا البرمجي
# </h2>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# هناك مهارتان أساسيتان في تطوير البرمجيات يُعرَّف بهما المبتدئون في مراحل مبكرة:
# <strong>التجريد (<span dir="ltr" style="unicode-bidi: isolate;">Abstraction</span>)</strong>
# و<strong>التفكيك (<span dir="ltr" style="unicode-bidi: isolate;">Decomposition</span>)</strong>.
# وهذان المفهومان مهمّان للغاية أيضًا للعلماء الذين يطوّرون شيفرات بحثية.
# </p>
#
# <ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>التجريد</strong> يعني تمثيل العناصر الجوهرية فقط في سير العمل أو في النظام.
# </li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>التفكيك</strong> يعني تقسيم سير عمل (أو نظام) معقّد إلى سلسلة من الخطوات (أو المكوّنات) المرتّبة والمترابطة.
# </li>
# </ul>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# توضح فاليري شوت وزملاؤها أن هاتين المهارتين تُعدّان أساسيتين لمفهوم
# <a href="https://doi.org/10.1016/j.edurev.2017.09.003" dir="ltr">التفكير الحاسوبي</a>،
# وبالتالي فهما جوهريتان للعلوم الحاسوبية.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# سنطبّق هذين المفهومين باستخدام مؤشر رضا متطلبات المياه
# <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span>،
# وهو مؤشر موصوف بالتفصيل في
# <a href="https://iridl.ldeo.columbia.edu/documentation/usgs/adds/wrsi/.WRSI_readme.pdf" dir="ltr">هذا المستند</a>
# الذي أعدّه أحد مؤلفيه الأصليين.
# <strong>كيف يمكننا تفكيك</strong>
# <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span>
# <strong>إلى سلسلة من الخطوات القابلة للتنفيذ في</strong>
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>؟
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🏁 تحدٍّ
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# إذا كنت مهتمًا بظروف المحاصيل وبحساب موازين المياه باستخدام بيانات الاستشعار عن بُعد، فهذه فرصة ممتازة لتحدّي نفسك. اقرأ عن
# <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span>
# (المستند المشار إليه أعلاه غالبًا هو المورد الوحيد الذي تحتاج إليه)، ثم اكتب خطة لكيفية تنفيذ
# <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span>
# في
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>
# استنادًا إلى ما تعلّمناه في الوحدات السابقة. لا حاجة لإعادة كتابة المعادلات؛ بل ركّز على تحديد البيانات المطلوبة وما ستكون مخرجات كل خطوة.
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>هذه هي الخطوات التي توصّلنا إليها لحساب</strong>
# <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span>:
# </p>
#
# <ol dir="rtl" style="direction: rtl; unicode-bidi: plaintext; text-align: right; padding-right: 1.2em;">
#
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>حساب <span dir="ltr" style="unicode-bidi: isolate;">PET</span></strong>، وهو مقدار الطاقة المتاحة لتبخير الماء. الجزء من هذه الطاقة الذي يُستهلك فعليًا في تبخير الماء يُعرف بالنتح-التبخر الفعلي
# <span dir="ltr" style="unicode-bidi: isolate;">AET</span>.
# سنحصل على تقديرات أسبوعية متسقة لكل من
# <span dir="ltr" style="unicode-bidi: isolate;">PET</span>
# و<span dir="ltr" style="unicode-bidi: isolate;">AET</span>
# من منتج
# <span dir="ltr" style="unicode-bidi: isolate;">NASA VIIRS VNP16</span>
# الذي يستخدم الخوارزمية نفسها المستخدمة في
# <span dir="ltr" style="unicode-bidi: isolate;">MODIS MOD16</span>
# (<a href="https://github.com/OpenClimateScience/M3-Open-Science-for-Water-Resources" dir="ltr">تذكّر أننا استخدمنا هذه البيانات في الوحدة 3</a>).
# </li>
#
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>تعريف الماء المتاح في التربة</strong>. يمكننا حساب ماء التربة (مم) إذا عرفنا
# <strong>المحتوى الحجمي للماء</strong>
# <span dir="ltr" style="unicode-bidi: isolate;">VWC</span>
# و<strong>عمق الجذور</strong>.
# سنقدّر
# <span dir="ltr" style="unicode-bidi: isolate;">VWC</span>
# اعتمادًا على ميزانية مائية سنوية مبسّطة، وسنستخدم أعماق جذور تمثيلية من منظمة الأغذية والزراعة
# <span dir="ltr" style="unicode-bidi: isolate;">FAO</span>.
# </li>
#
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>حساب مستوى الماء الحرج في التربة</strong>. وهو مقدار الماء الذي يكون «أكثر من كافٍ» لتلبية احتياجات المحصول، ويمثّل الحد الأدنى اللازم لضمان الاستخدام الكامل للطاقة المتاحة لتبخير الماء (أي
# <span dir="ltr" style="unicode-bidi: isolate;">PET</span>).
# سنحسبه اعتمادًا على سعة احتفاظ التربة بالماء ومعاملات أخرى معرّفة في
# <span dir="ltr" style="unicode-bidi: isolate;">FAO</span>.
# </li>
#
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>حساب الماء المتاح للنبات
# <span dir="ltr" style="unicode-bidi: isolate;">PAW</span></strong>؛
# وهو مقدار الماء الذي يستطيع النبات استخدامه فعليًا، ويُحدَّد من خلال ميزان الماء. سنحسب ماء التربة المتاح عند كل خطوة زمنية، ثم نضيف الهطول (إن وُجد) لحساب قيمة
# <span dir="ltr" style="unicode-bidi: isolate;">PAW</span>
# الجديدة عند كل خطوة. سنستخدم بيانات الهطول من
# <span dir="ltr" style="unicode-bidi: isolate;">NASA</span>.
# </li>
#
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>حساب
# <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span>
# لكل خطوة زمنية معطاة</strong>.
# </li>
#
# </ol>
#
# </div>
