# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h1 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">M5.1 – مشروع خطة إنشاء</h1><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">جزء من: <a href="https://github.com/OpenClimateScience/M5-Open-Science-for-Crops" dir="ltr">Open Climate Science for Crops &amp; Crop Conditions</a></p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">مقدمة</h2><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">في هذه الوحدة سنتعلم كيفية إنشاء برمجيات بحثية يمكن تثبيتها وتشغيلها بسهولة على حاسوب شخص آخر، بما يتيح له إعادة إنتاج نتائجنا العلمية. لقد رأينا طريقتين أخريين للقيام بذلك في الوحدتين <span dir="ltr" style="unicode-bidi: isolate;">3</span> و<span dir="ltr" style="unicode-bidi: isolate;">4</span>. وناقشنا أنه من أجل إعادة إنتاج نتائج مشروع حاسوبي:</p><ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">يجب أن تكون <strong>بيئة البرمجيات</strong> نفسها،</li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">ويجب أن تكون <strong>إصدارات الحزم</strong> المثبّتة نفسها،</li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">ويجب أن نشغّل <strong>الشيفرة نفسها</strong> على <strong>البيانات نفسها</strong>.</li>
# </ul><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">يعتمد الوصول إلى الشيفرة والبيانات التي استخدمها شخص ما لإنتاج نتيجة علمية على مدى التزامه بمبادئ العلم المفتوح. ينبغي أن يشارك الشيفرة والبيانات في مستودعات ذات مُعرّف فريد ودائم (مثل <span dir="ltr" style="unicode-bidi: isolate;">DOI</span>)، مع رخصة مفتوحة.</p><h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">إدارة سير العمل</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">كيف نضمن إعداد <strong>بيئة البرمجيات</strong> بالطريقة نفسها؟ نستخدم مدير بيئات لإنشاء بيئة افتراضية: تثبيت <span dir="ltr" style="unicode-bidi: isolate;">Python</span> خاص بالمشروع. ثم نستخدم <strong>مدير حزم</strong> لتبسيط تثبيت الحزم والتحقق من إصدار كل حزمة.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>في هذا الدرس سنقدم اعتبارًا ثالثًا لمشاريع البرمجيات العلمية القابلة لإعادة الإنتاج: إدارة سير العمل.</strong> لأن معالجة البيانات قد تتضمن خطوات عديدة وبيانات كبيرة، نريد أن نجعل إعادة إنتاج النتائج سهلة قدر الإمكان. من المثالي أن يتمكن المستخدم من تشغيل ملف تنفيذي (مثل «نقرة مزدوجة») ينفّذ كل شيء: من تنزيل البيانات إلى إنتاج الشكل النهائي. أدوات إدارة سير العمل تُقارب هذا الهدف. وإذا قارنا أدوات إدارة البيئة والحزم وسير العمل التي رأيناها في كل وحدة حتى الآن، فقد ننشئ جدولًا للمقارنة.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">مشروعنا البرمجي تخطيط</h2><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">هناك مهارتان أساسيتان في تطوير البرمجيات يُعرَّف بهما المبتدئون مبكرًا: <strong>التجريد (Abstraction)</strong> و<strong>التفكيك (Decomposition)</strong>. وهذان المفهومان مفيدان جدًا أيضًا للعلماء الذين يكتبون شيفرة بحثية.</p><ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>التجريد</strong> يعني تمثيل ما هو جوهري فقط في سير العمل أو النظام.</li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>التفكيك</strong> يعني تقسيم سير عمل (أو نظام) معقد إلى سلسلة من الخطوات (أو الأجزاء) المرتبة والمترابطة.</li>
# </ul><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">تصف فاليري شوت وزملاؤها كيف أن هاتين المهارتين أساسيتان لـ <a href="https://doi.org/10.1016/j.edurev.2017.09.003" dir="ltr">«التفكير الحاسوبي»</a>، وبالتالي أساسيتان للعلوم الحاسوبية.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">سنمارس كلا المفهومين باستخدام مؤشر رضا متطلبات المياه <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span>، <a href="https://iridl.ldeo.columbia.edu/documentation/usgs/adds/wrsi/.WRSI_readme.pdf" dir="ltr">الموصوف بالتفصيل في هذا الملف</a> الذي أعدّه أحد مؤلفيه الأصليين. <strong>كيف يمكننا تفكيك</strong> <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span> <strong>إلى سلسلة خطوات يمكن تنفيذها في</strong> <span dir="ltr" style="unicode-bidi: isolate;">Python</span>؟</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🏁 تحدٍّ</h4><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">إذا كنت مهتمًا بظروف المحاصيل وبحساب موازين المياه من بيانات الاستشعار عن بُعد، فهذه فرصة ممتازة لتحدي نفسك. اقرأ عن <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span> (الملف المشار إليه أعلاه غالبًا هو المورد الوحيد الذي تحتاجه) ثم دوّن كيف ستنفّذ <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span> في <span dir="ltr" style="unicode-bidi: isolate;">Python</span> اعتمادًا على ما تعلمناه في الوحدات السابقة. لا تحتاج إلى إعادة كتابة المعادلات؛ بل فكّر في البيانات المطلوبة وما ستكون مخرجات كل خطوة.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>هذه هي الخطوات التي توصلنا إليها لحساب</strong> <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span>:</p><ol dir="rtl" style="direction: rtl; unicode-bidi: plaintext; text-align: right; padding-right: 1.2em;"><li style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong><span dir="ltr" style="unicode-bidi: isolate;">PET</span> حساب،</strong> أو مقدار الطاقة المتاحة لتبخير الماء. الجزء من هذه الطاقة الذي يُستهلك فعليًا لتبخير الماء هو النتح-التبخر الفعلي <span dir="ltr" style="unicode-bidi: isolate;">AET</span>. سنحصل على تقديرات أسبوعية متسقة لكل من <span dir="ltr" style="unicode-bidi: isolate;">PET</span> و<span dir="ltr" style="unicode-bidi: isolate;">AET</span> من منتج <span dir="ltr" style="unicode-bidi: isolate;">NASA</span> <span dir="ltr" style="unicode-bidi: isolate;">VIIRS VNP16</span> الذي يستخدم الخوارزمية نفسها مثل <span dir="ltr" style="unicode-bidi: isolate;">MODIS MOD16</span> (<a href="https://github.com/OpenClimateScience/M3-Open-Science-for-Water-Resources" dir="ltr">تذكّر أننا استخدمنا هذه البيانات في الوحدة 3</a>).</li><li style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>التربة المتاحة ماء تعريف.</strong> يمكننا حساب ماء التربة (مم) إذا عرفنا <strong>المحتوى الحجمي للماء</strong> <span dir="ltr" style="unicode-bidi: isolate;">VWC</span> و<strong>عمق الجذور</strong>. سنقرّب <span dir="ltr" style="unicode-bidi: isolate;">VWC</span> اعتمادًا على ميزانية مائية سنوية مبسطة. وسنستخدم أعماق جذور تمثيلية من منظمة الأغذية والزراعة <span dir="ltr" style="unicode-bidi: isolate;">FAO</span>.</li><li style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>الحرج التربة ماء مستوى حساب.</strong> وهو مقدار الماء الذي يكون «أكثر من كافٍ» لتلبية احتياجات المحصول، كما يمثل الحد الأدنى اللازم لضمان استخدام كامل الطاقة المتاحة لتبخير الماء (أي <span dir="ltr" style="unicode-bidi: isolate;">PET</span>). سنحسبه اعتمادًا على سعة احتفاظ التربة بالماء ومعاملات أخرى معرفة في <span dir="ltr" style="unicode-bidi: isolate;">FAO</span>.</li><li style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>للنبات المتاحة الماء حساب <span dir="ltr" style="unicode-bidi: isolate;">PAW</span>؛</strong> وهو مقدار الماء الذي يستطيع النبات استخدامه فعليًا ويحدده ميزان الماء. سنحتاج إلى حساب ماء التربة المتاح عند كل خطوة زمنية، ثم إضافة الهطول (إن وُجد) لحساب <span dir="ltr" style="unicode-bidi: isolate;">PAW</span> الجديد عند كل خطوة. سنستخدم بيانات هطول من <span dir="ltr" style="unicode-bidi: isolate;">NASA</span>.</li><li style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>للخطوة الزمنية المعطاة <span dir="ltr" style="unicode-bidi: isolate;">WRSI</span> حساب.</strong></li></ol>
# </div>
