# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h1 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <span dir="ltr" style="unicode-bidi: isolate;">M5.2</span> – إنشاء بيئة بحثية قابلة لإعادة الإنتاج
# </h1>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# جزء من:
# <a href="https://github.com/OpenClimateScience/M5-Open-Science-for-Crops" dir="ltr">
# علوم المناخ المفتوحة للمحاصيل وظروفها
# </a>
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# في هذا الدرس سنقدّم أداتين جديدتين لإنشاء وإدارة بيئات بحثية قابلة لإعادة الإنتاج:
# </strong>
# </p>
#
# <ul>
#
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong><span dir="ltr" style="unicode-bidi: isolate;">Pixi</span></strong>
# هو مدير حزم يمكنه تثبيت وتحديث حزم
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>
# ومكوّنات أخرى ضمن بيئة البرمجيات. ويُعدّ بديلًا عن
# <span dir="ltr" style="unicode-bidi: isolate;">pip</span>
# الذي يقتصر على إدارة حزم
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span> فقط.
# </li>
#
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong><span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span></strong>
# أداة لإدارة سير العمل تتيح كتابة المهام البرمجية وتنفيذها من خلال أوامر بسيطة، غالبًا عبر تعليمة واحدة في سطر الأوامر.
# </li>
#
# </ul>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# معًا، ستمكّننا أداتا
# <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# و<span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span>
# من إعادة إنشاء بيئة برمجيات بحثية بسهولة، وتثبيت جميع الاعتمادات اللازمة، وتنفيذ سير العمل باستخدام عدد محدود من الأوامر البسيطة.
# </strong>
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# أدوات سطر الأوامر
# </h2>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# في هذه المرحلة ربما أصبحت أكثر تمرّسًا في استخدام أدوات سطر الأوامر على حاسوبك.
# </strong>
# ستجد إرشادات أقل تفصيلًا في هذا الدرس، لكن تذكّر أنه لتشغيل أوامر مثل
# <span dir="ltr" style="unicode-bidi: isolate;">cd</span>
# أو
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# أو
# <span dir="ltr" style="unicode-bidi: isolate;">snakemake</span>
# يجب استخدام بيئة سطر الأوامر المناسبة لنظام التشغيل لديك.
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 Windows
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# على نظام
# <span dir="ltr" style="unicode-bidi: isolate;">Windows</span>
# قم بتشغيل هذه الأوامر باستخدام
# <span dir="ltr" style="unicode-bidi: isolate;">PowerShell</span>
# أو
# <span dir="ltr" style="unicode-bidi: isolate;">Command Prompt</span>.
# </strong>
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🍎 🐧 Mac OS أو GNU/Linux
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# على نظام
# <span dir="ltr" style="unicode-bidi: isolate;">macOS</span>
# أو
# <span dir="ltr" style="unicode-bidi: isolate;">GNU/Linux</span>
# قم بتشغيل هذه الأوامر باستخدام
# <span dir="ltr" style="unicode-bidi: isolate;">Terminal</span>.
# </strong>
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <hr>
#
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# البدء مع <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# </h2>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# لتثبيت
# <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# وأداة سطر الأوامر
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>:
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 Windows
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <a href="https://pixi.sh/latest/installation/" dir="ltr">
# على نظام Windows، راجع تعليمات التثبيت على الموقع الرسمي
# </a>
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🍎 🐧 macOS أو GNU/Linux
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code># If you have curl installed:
# curl -fsSL https://pixi.sh/install.sh | sh
#
# # Otherwise:
# wget -qO- https://pixi.sh/install.sh | sh</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# ملاحظة: من الحكمة توخّي الحذر عند تنفيذ أمر يقوم بتشغيل سكربت مباشرةً من الإنترنت.
# <a href="https://pixi.sh/latest/installation/" dir="ltr">
# راجع الموقع الرسمي لـ Pixi بنفسك، حيث يمكنك معاينة السكربت قبل تشغيله
# </a>
# إذا رغبت في التحقق من مصدره.
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# إنشاء بيئة باستخدام <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# في البداية نحتاج إلى إنشاء بيئة باستخدام
# <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>.
# يشبه ذلك ما قمنا به في الوحدة 3
# (<a href="https://github.com/OpenClimateScience/M3-Open-Science-for-Water-Resources/blob/main/notebooks/01_Creating_a_Research_Software_Environment.ipynb" dir="ltr">
# إنشاء بيئة افتراضية باستخدام virtualenv
# </a>).
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 🍎 🐧 جميع أنظمة التشغيل
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code># Go to the directory we want to work in
# cd demo-M3-project
#
# pixi init</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# عند تنفيذ
# <span dir="ltr" style="unicode-bidi: isolate;">pixi init</span>
# من دون معاملات إضافية، ينشئ
# <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# بيئة باسم المجلد الحالي. وإذا أردنا إنشاء مجلد جديد يحمل اسم البيئة، يمكننا كتابة:
# <span dir="ltr" style="unicode-bidi: isolate;">pixi init name</span>،
# حيث يشير
# <span dir="ltr" style="unicode-bidi: isolate;">name</span>
# إلى اسم البيئة المراد إنشاؤها.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>ماذا حدث؟</strong>
# ظهر الآن ملف باسم
# <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>
# داخل هذا المجلد. ينبغي أن يبدو تقريبًا كما يلي:
# </p>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>[workspace]
# authors = ["K. Arthur Endsley &lt;arthur.endsley@ntsg.umt.edu&gt;"]
# channels = ["conda-forge"]
# name = "demo-M5-project"
# platforms = ["linux-64"]
# version = "0.1.0"
#
# [tasks]
#
# [dependencies]</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# هذا المثال مأخوذ من حاسوبي. جاءت معلومات
# <span dir="ltr" style="unicode-bidi: isolate;">authors</span>
# من إعدادات
# <span dir="ltr" style="unicode-bidi: isolate;">Git</span>،
# لأنني استخدمت
# <span dir="ltr" style="unicode-bidi: isolate;">git config</span>
# لضمان أن
# <span dir="ltr" style="unicode-bidi: isolate;">Git</span>
# يعرف اسمي وبريد حساب
# <span dir="ltr" style="unicode-bidi: isolate;">GitHub</span>.
# لذلك لا تقلق إذ

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# التوافق مع <span dir="ltr" style="unicode-bidi: isolate;">pyproject.toml</span>
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# يستخدم
# <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# صيغة خاصة لملف
# <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>،
# وقد تكون مشابهة لملف
# <span dir="ltr" style="unicode-bidi: isolate;">pyproject.toml</span>
# الذي اطّلعنا عليه في الوحدة 4. إذا رغبت في أن يستخدم
# <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# صيغة
# <span dir="ltr" style="unicode-bidi: isolate;">pyproject.toml</span>،
# فيمكنك إضافة المعامل
# <span dir="ltr" style="unicode-bidi: isolate;">--format pyproject</span>.
# على سبيل المثال:
# </p>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi init --format pyproject</code></pre>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# تفعيل بيئتنا الافتراضية
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# لمتابعة إعداد البيئة، نحتاج إلى تفعيل البيئة الافتراضية. يُستخدم الأمر
# <span dir="ltr" style="unicode-bidi: isolate;">pixi shell</span>
# لأن مصطلح
# <span dir="ltr" style="unicode-bidi: isolate;">shell</span>
# يشير إلى واجهة سطر الأوامر الخاصة بنظام التشغيل.
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 🍎 🐧 جميع أنظمة التشغيل
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi shell</code></pre>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# إضافة الاعتمادات البرمجية باستخدام <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# لنرَ كيف يمكننا استخدام
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# لإدارة الاعتمادات البرمجية. سابقًا استخدمنا
# <span dir="ltr" style="unicode-bidi: isolate;">pip</span>
# لتثبيت حزم
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>.
# إلا أن
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# يمكنه إدارة ما هو أكثر من حزم
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>؛ إذ يستطيع إدارة منصّات برمجية كاملة، بما في ذلك مُفسّر
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>
# نفسه.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# على سبيل المثال، لنُخبر
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# أننا نريد تضمين
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>
# في مشروعنا:
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 🍎 🐧 جميع أنظمة التشغيل
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add python</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# هذا الأمر لا يثبّت مُفسّر
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>
# فحسب، بل يُخبر
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# أن العناصر التي سنضيفها لاحقًا قد تكون وحدات
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>،
# وأنه ينبغي البحث عنها في مستودعات مثل
# <span dir="ltr" style="unicode-bidi: isolate;">PyPI</span>.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# كيف نثبّت حزم
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>؟
# باستخدام الأمر نفسه:
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 🍎 🐧 جميع أنظمة التشغيل
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code># Install the numpy package for Python
# pixi add numpy</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# ستلاحظ ظهور أشرطة تقدّم بينما يقوم
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# بتحديد الحزمة المطلوبة، واختيار أحدث إصدار (لأننا لم نحدّد إصدارًا معيّنًا)، وتنزيلها، وتثبيت اعتماداتها، ثم تثبيت الحزمة نفسها. هذا سلوك متوقّع.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# لنلقِ نظرة مجددًا على ملف
# <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>.
# ستلاحظ تحديث قسم
# <span dir="ltr" style="unicode-bidi: isolate;">[dependencies]</span>،
# على سبيل المثال:
# </p>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>[dependencies]
# numpy = "&gt;=2.3.5,&lt;3"</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# قد تلاحظ أيضًا وجود ملف باسم
# <span dir="ltr" style="unicode-bidi: isolate;">pixi.lock</span>.
# <a href="https://pixi.sh/latest/workspace/lockfile/" dir="ltr">
# يمكنك قراءة المزيد عنه هنا
# </a>،
# لكننا لن نتعمّق فيه، إذ لا نحتاج إلى فهم آليته الداخلية لإدارة بيئة قابلة لإعادة الإنتاج. جميع المعلومات الأساسية التي نحتاجها موجودة في ملف
# <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>.
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <hr>
#
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# إدارة تعارضات الإصدارات
# </h2>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# يجب أن يكون مدير الحزم الجيد قادرًا على التعامل مع التعارضات بين الحزم المختلفة وبين إصدارات اعتماداتها. في الوحدة 3 ناقشنا كيف يمكن أن يصبح مشروعنا معتمدًا على إصدار محدد من اعتماد برمجي. وعندما يعتمد مشروعنا على إصدارات محددة من حزمة أو أكثر، فقد يتعارض ذلك مع متطلبات اعتماد آخر.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# في هذا المشروع نحتاج إلى التأكد من استخدام إصدار من
# <span dir="ltr" style="unicode-bidi: isolate;">numpy</span>
# <strong>أقل من</strong>
# <span dir="ltr" style="unicode-bidi: isolate;">2.0</span>.
# أحدث إصدار يسبق
# <span dir="ltr" style="unicode-bidi: isolate;">2.0</span>
# هو
# <span dir="ltr" style="unicode-bidi: isolate;">1.26.3</span>.
# هذا الإصدار لديه اعتمادات خاصة، وأهمها
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>،
# وقد صُمّم ليعمل فقط مع إصدارات معيّنة من
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>.
# <strong>
# كيف نضمن تثبيت الإصدار الصحيح من
# <span dir="ltr" style="unicode-bidi: isolate;">numpy</span>
# وكذلك الإصدار الصحيح من
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>؟
# </strong>
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# يتعامل
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# ومديرو الحزم الآخرون مع هذه المسألة بسلاسة. ولكن لضمان امتلاك
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# جميع المعلومات المتعلقة بالتعارضات المحتملة،
# <strong>
# نحتاج إلى تثبيت الحزم التي قد تتعارض في الوقت نفسه.
# </strong>
# في هذا المثال يعني ذلك تثبيت
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>
# وإصدار من
# <span dir="ltr" style="unicode-bidi: isolate;">numpy</span>
# أقل من
# <span dir="ltr" style="unicode-bidi: isolate;">2.0</span>
# ضمن أمر واحد.
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 🍎 🐧 جميع أنظمة التشغيل
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add python "numpy&lt;2"</code></pre>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 👈 إعداد البيئة تلقائيًا
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# لكن انتظر! من المفترض أن يجعل
# <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# إعداد البيئة أمرًا سهلًا، فلماذا نقوم بتثبيت كل حزمة يدويًا؟
# </strong>
# نحن الآن نتعلّم استخدام
# <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# للمرة الأولى. ولكن إذا واجهت صعوبات أو رغبت في تجاوز الخطوات التفصيلية، فلاحظ أن هناك بالفعل ملف
# <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>
# ضمن هذا المستودع. يمكنك إعداد البيئة تلقائيًا استنادًا إلى ملف
# <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>
# الموجود مسبقًا عبر تنفيذ الأمر التالي:
# </p>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code># Must be in the directory of the pixi.toml file
# pixi install</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# إذا اخترت استخدام
# <span dir="ltr" style="unicode-bidi: isolate;">pixi install</span>،
# فمن الأفضل متابعة بقية هذا الدرس لفهم كيفية عمل
# <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>
# وإدارة الاعتمادات بشكل قابل لإعادة الإنتاج.
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# تثبيت الاعتمادات المتبقية
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# لنقم بتثبيت بقية الاعتمادات التي سنحتاج إليها في هذا الدرس.
# </strong>
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 🍎 🐧 جميع أنظمة التشغيل
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add earthaccess netcdf4 h5py matplotlib pyproj py4eos rasterio rioxarray shapely xarray notebook</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# قد تواجه الخطأ التالي:
# </strong>
# </p>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>Error:   × failed to solve requirements of environment...
#   ├─▶   × failed to solve the environment
#   │
#   ╰─▶ Cannot solve the request because of: No candidates were found for py4eos *.</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# يحدث هذا أحيانًا مع بعض الحزم المتاحة في
# <span dir="ltr" style="unicode-bidi: isolate;">PyPI</span>
# ولكن لم يتم اكتشافها تلقائيًا—وغالبًا لأن
# <span dir="ltr" style="unicode-bidi: isolate;">conda</span>
# لا يفهرسها. لضمان أن يقوم
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# بالبحث في
# <span dir="ltr" style="unicode-bidi: isolate;">PyPI</span>،
# نضيف المعامل
# <span dir="ltr" style="unicode-bidi: isolate;">--pypi</span>:
# </p>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add --pypi py4eos</code></pre>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🚩 <span style="color:red">تنبيه</span>
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# بما أن الأمر الأصلي فشل، لم يتم تثبيت أيٍّ من الحزم الأخرى (باستثناء
# <span dir="ltr" style="unicode-bidi: isolate;">py4eos</span>).
# </strong>
# لذلك يجب إعادة تنفيذ أمر
# <span dir="ltr" style="unicode-bidi: isolate;">pixi add</span>
# لتثبيت بقية الاعتمادات.
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 🍎 🐧 جميع أنظمة التشغيل
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add earthaccess netcdf4 h5py matplotlib pyproj rasterio rioxarray xarray shapely notebook</code></pre>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <hr>
#
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# توثيق بيئتك
# </h2>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# لقد أنشأنا بيئة
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>
# وثبّتنا جميع الاعتمادات اللازمة—رائع. ولكن كيف نجعل ذلك أكثر سهولة من حيث إعادة الإنتاج؟
# </p>
#
# <ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# إذا احتجنا إلى بدء العمل على جهاز آخر ضمن المشروع نفسه، فسنضطر إلى تنفيذ جميع هذه الأوامر مرة أخرى.
# </li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# وإذا أراد شخص آخر إعادة إنتاج عملنا أو المساهمة فيه، فنريد التأكد من أنه أعد جهازه بالطريقة نفسها.
# </li>
# </ul>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# يمثل ملف
# <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>
# وصفًا كاملًا للبيئة التي أنشأناها. إذا فتحت الملف، ستلاحظ أنه يحتوي تلقائيًا على جميع الاعتمادات التي قمنا بتثبيتها. (المثال أدناه يوضح شكل قسم الاعتمادات):
# </p>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>[dependencies]
# python = "&gt;=3.12.12,&lt;3.13"
# numpy = "&lt;2"
# earthaccess = "&gt;=0.15.1,&lt;0.16"
# netcdf4 = "&gt;=1.7.3,&lt;2"
# h5py = "&gt;=3.15.1,&lt;4"
# matplotlib = "&gt;=3.10.8,&lt;4"
# pyproj = "&gt;=3.7.2,&lt;4"
# rasterio = "&gt;=1.4.4,&lt;2"
# rioxarray = "&gt;=0.20.0,&lt;0.21"
# xarray = "&gt;=2025.12.0,&lt;2026"
# notebook = "&gt;=7.5.1,&lt;8"
# shapely = "&gt;=2.1.2,&lt;3"
#
# [pypi-dependencies]
# py4eos = "&gt;=0.5.0, &lt;0.6"</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# ولكن إذا كنت تعمل مع شخص لا يملك
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# ولا يرغب في تثبيته، فلن يتمكن من استخدام
# <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>.
# وإذا كان يستخدم
# <span dir="ltr" style="unicode-bidi: isolate;">mamba</span>
# أو
# <span dir="ltr" style="unicode-bidi: isolate;">conda</span>،
# فيمكنك تصدير ملف بيئة بصيغة
# <span dir="ltr" style="unicode-bidi: isolate;">conda YAML</span>.
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 🍎 🐧 جميع أنظمة التشغيل
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi workspace export conda-environment</code></pre>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🍎 🐧 macOS و GNU/Linux
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# على
# <span dir="ltr" style="unicode-bidi: isolate;">macOS</span>
# و<span dir="ltr" style="unicode-bidi: isolate;">GNU/Linux</span>
# يمكنك توجيه المخرجات إلى ملف:
# </p>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi workspace export conda-environment &gt; environment.yaml</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# يمكن الآن مشاركة ملف
# <span dir="ltr" style="unicode-bidi: isolate;">environment.yaml</span>
# مع أي شخص يرغب في إعادة إنشاء البيئة البرمجية.
# </strong>
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <hr>
#
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# البدء مع <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span>
# </h2>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# حتى الآن لدينا مدير حزم
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>
# يشبه في قدراته
# <span dir="ltr" style="unicode-bidi: isolate;">pip</span>.
# يمكننا تثبيت حزم
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>
# وإنشاء لقطة من البيئة يمكن إعادة استخدامها ومشاركتها لضمان إعادة إنشاء البيئة الحاسوبية على جهاز آخر.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# لكن هذا لا يعالج سوى نصف المشكلة.
# </strong>
# ما زلنا بحاجة إلى طريقة سهلة لإعادة إنتاج <strong>سير العمل</strong> الذي سننشئه؛ أي آلية لا تقتصر على تثبيت البيئة فحسب، بل تضمن تشغيل البرامج <strong>بالطريقة نفسها</strong> التي استخدمناها.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# من الأدوات المبكرة لمعالجة هذه المسألة برنامج يُسمى
# <span dir="ltr" style="unicode-bidi: isolate;">make</span>.
# كان يتيح تشغيل سلسلة كاملة من المهام المعقدة عبر أوامر بسيطة مثل
# <span dir="ltr" style="unicode-bidi: isolate;">make install</span>
# أو
# <span dir="ltr" style="unicode-bidi: isolate;">make results.csv</span>.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# في هذا الدرس سنستخدم أداة مشابهة لـ
# <span dir="ltr" style="unicode-bidi: isolate;">make</span>
# تُسمّى
# <a href="https://snakemake.github.io/" dir="ltr">Snakemake</a>.
# </strong>
# ولتثبيت
# <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span>
# باستخدام
# <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>:
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 🍎 🐧 جميع أنظمة التشغيل
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add --pypi Snakemake</code></pre>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# إنشاء القواعد
# </h3>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# تُستخدم
# <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span>
# لأتمتة المهام، مثل مهام سير العمل العلمي.
# </strong>
# تُعرَّف كل مهمة من خلال <strong>قاعدة</strong>
# <span dir="ltr" style="unicode-bidi: isolate;">rule</span>،
# وغالبًا ما تتضمن تحديد ملفات الإدخال وملفات الإخراج المطلوبة.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# كما في حلقات
# <span dir="ltr" style="unicode-bidi: isolate;">for</span>
# أو عند تعريف الدوال في
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>،
# تتضمن القواعد كلمة مفتاحية تليها نقطتان
# <span dir="ltr" style="unicode-bidi: isolate;">:</span>
# ثم كتلة من الشيفرة. صياغة
# <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span>
# هي امتداد للغة
# <span dir="ltr" style="unicode-bidi: isolate;">Python</span>.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# مثال بسيط جدًا قد يبدو كما يلي:
# </p>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code># Snakefile
# rule greeting:
#     shell: "echo Hello, world!"</code></pre>
#
# <ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# بدلًا من
# <span dir="ltr" style="unicode-bidi: isolate;">def</span>
# أو
# <span dir="ltr" style="unicode-bidi: isolate;">for</span>
# نستخدم العبارة
# <span dir="ltr" style="unicode-bidi: isolate;">rule</span>
# لتعريف قاعدة جديدة.
# </li>
#
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# الكتلة المزاحة بعد النقطتين تحتوي جميع التعليمات المتعلقة بهذه القاعدة.
# </li>
#
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# الخاصية
# <span dir="ltr" style="unicode-bidi: isolate;">shell</span>
# هي المكان الذي نكتب فيه الأمر الذي يجب تشغيله في سطر الأوامر لتنفيذ المهمة. في هذا المثال سيتم تشغيل الأمر
# <span dir="ltr" style="unicode-bidi: isolate;">echo Hello, world!</span>.
# </li>
# </ul>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# <strong>
# افتح محرر نصوص وضع القاعدة أعلاه في ملف نصي عادي باسم
# <span dir="ltr" style="unicode-bidi: isolate;">Snakefile</span>
# (من دون امتداد).
# </strong>
# ثم نفّذ القاعدة باستخدام الأمر التالي:
# </p>
#
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# 🪟 🍎 🐧 جميع أنظمة التشغيل
# </h3>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>snakemake greeting --cores=1 --quiet</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# ينبغي أن ترى مخرجات مشابهة لما يلي:
# </p>
#
# <pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>Assuming unrestricted shared filesystem usage.
# host: Gullveig
# Building DAG of jobs...
# Using shell: /usr/bin/bash
# Select jobs to execute...
# Execute 1 jobs...
# Hello, world!
# Complete log(s): /usr/local/dev/demo-M5-project/.snakemake/log/2025-12-12T152205.384447.snakemake.log</code></pre>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# قد يكون من الصعب ملاحظة ذلك وسط الأسطر الإضافية التي يطبعها
# <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span>،
# لكنه نفّذ المهمة فعليًا وطبع
# <span dir="ltr" style="unicode-bidi: isolate;">Hello, world!</span>
# على الشاشة.
# </p>
#
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# سنواصل في الدروس التالية بناء قواعد أكثر واقعية تربط ملفات الإدخال والإخراج، وتسمح بإعادة تشغيل الأجزاء الضرورية فقط عند تغيّر البيانات أو الشيفرة.
# </p>
#
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
#
# <hr>
#
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# موارد إضافية
# </h2>
#
# <ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">
# اقرأ عن الكيفية التي تُحدث بها أدوات إدارة سير العمل، مثل
# <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span>،
# تحوّلًا في العلوم الحاسوبية
# (<a href="https://doi.org/10.1038/d41586-019-02619-z" dir="ltr">Nature</a>).
# </li>
# </ul>
#
# </div>
