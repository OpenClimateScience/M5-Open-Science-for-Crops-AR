# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h1 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">M5.2 – قابلة لإعادة الإنتاج بحثية بيئة إنشاء</h1><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">جزء من: <a href="https://github.com/OpenClimateScience/M5-Open-Science-for-Crops" dir="ltr">Open Climate Science for Crops &amp; Crop Conditions</a></p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>في هذا الدرس سنقدم أداتين جديدتين لإنشاء وإدارة بيئات بحثية قابلة لإعادة الإنتاج:</strong></p><ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong><span dir="ltr" style="unicode-bidi: isolate;">Pixi</span></strong> هو مدير حزم يمكنه تثبيت وتحديث حزم <span dir="ltr" style="unicode-bidi: isolate;">Python</span> وأجزاء أخرى من بيئة البرمجيات. وهو بديل عن <span dir="ltr" style="unicode-bidi: isolate;">pip</span> الذي يدير حزم <span dir="ltr" style="unicode-bidi: isolate;">Python</span> فقط.</li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong><span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span></strong> أداة لكتابة المهام البرمجية وتنفيذها عبر تعليمات بسيطة من سطر واحد.</li>
# </ul><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>معًا، سيسمح لنا</strong> <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span> و<span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span> <strong>بإعادة إنشاء بيئة برمجيات بحثية بسهولة، وتثبيت جميع الاعتمادات اللازمة، وتنفيذ سير العمل بعدد صغير من الأوامر البسيطة.</strong></p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">أدوات سطر الأوامر</h2><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>في هذه المرحلة ربما أصبحت متمرسًا جدًا في استخدام أدوات سطر الأوامر على حاسوبك.</strong> ستجد تلميحات أقل في هذا الدرس، لكن تذكّر: لتشغيل أوامر مثل <span dir="ltr" style="unicode-bidi: isolate;">cd</span> أو <span dir="ltr" style="unicode-bidi: isolate;">pixi</span> أو <span dir="ltr" style="unicode-bidi: isolate;">snakemake</span>…</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 Windows</h4><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>على Windows شغّل هذه الأوامر في</strong> <span dir="ltr" style="unicode-bidi: isolate;">PowerShell</span> أو <span dir="ltr" style="unicode-bidi: isolate;">Command Prompt</span>.</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🍎 🐧 Mac OS/X أو GNU/Linux</h4><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>على Mac OS/X أو GNU/Linux شغّل هذه الأوامر في</strong> <span dir="ltr" style="unicode-bidi: isolate;">Terminal</span>.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><hr></p><h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><span dir="ltr" style="unicode-bidi: isolate;">Pixi</span> مع البدء</h2><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">لتثبيت <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span> وأداة سطر الأوامر <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>:</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 Windows</h4><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><a href="https://pixi.sh/latest/installation/" dir="ltr">على Windows راجع تعليمات التثبيت على موقعهم</a></p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🍎 🐧 Mac OS/X أو GNU/Linux</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code># If you have curl installed:
# curl -fsSL https://pixi.sh/install.sh | sh
#
# # Otherwise:
# wget -qO- https://pixi.sh/install.sh | sh</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">ملاحظة: بوجه عام من الحكمة الحذر من أمر يقوم بتشغيل سكربت من الإنترنت. <a href="https://pixi.sh/latest/installation/" dir="ltr">راجع موقع Pixi بنفسك حيث يمكنك معاينة السكربت</a> إذا أردت التحقق من مصدره.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><span dir="ltr" style="unicode-bidi: isolate;">Pixi</span> باستخدام بيئة إنشاء</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">في البداية نحتاج إلى إنشاء بيئة باستخدام <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>. هذا مشابه لما فعلناه في الوحدة 3 (<a href="https://github.com/OpenClimateScience/M3-Open-Science-for-Water-Resources/blob/main/notebooks/01_Creating_a_Research_Software_Environment.ipynb" dir="ltr">إنشاء بيئة افتراضية باستخدام virtualenv</a>).</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code># Go to the directory we want to work in
# cd demo-M3-project
#
# pixi init</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">عند تنفيذ <span dir="ltr" style="unicode-bidi: isolate;">pixi init</span> بدون معاملات إضافية، ينشئ <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span> بيئة باسم المجلد الحالي. وإذا أردنا إنشاء مجلد جديد باسم البيئة يمكننا كتابة: <span dir="ltr" style="unicode-bidi: isolate;">pixi init name</span> حيث <span dir="ltr" style="unicode-bidi: isolate;">name</span> هو اسم البيئة.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>ماذا حدث؟</strong> ظهر الآن ملف باسم <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span> في هذا المجلد. ينبغي أن يبدو تقريبًا كما يلي:</p><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>[workspace]
# authors = [&quot;K. Arthur Endsley &lt;arthur.endsley@ntsg.umt.edu&gt;&quot;]
# channels = [&quot;conda-forge&quot;]
# name = &quot;demo-M5-project&quot;
# platforms = [&quot;linux-64&quot;]
# version = &quot;0.1.0&quot;
#
# [tasks]
#
# [dependencies]</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">هذا المثال من حاسوبي. جاءت معلومات <span dir="ltr" style="unicode-bidi: isolate;">authors</span> من إعدادات <span dir="ltr" style="unicode-bidi: isolate;">Git</span> لأنني استخدمت <span dir="ltr" style="unicode-bidi: isolate;">git config</span> لضمان أن <span dir="ltr" style="unicode-bidi: isolate;">Git</span> يعرف اسمي وبريد حساب <span dir="ltr" style="unicode-bidi: isolate;">GitHub</span>. لذلك لا تقلق إذا رأيت معلومات شخصية في هذا الملف.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><span dir="ltr" style="unicode-bidi: isolate;">pyproject.toml</span> مع التوافق</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">لدى <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span> صيغة خاصة لملف <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>، وقد تشبه ملف <span dir="ltr" style="unicode-bidi: isolate;">pyproject.toml</span> الذي رأيناه في الوحدة 4. إذا أردت أن يستخدم <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span> صيغة <span dir="ltr" style="unicode-bidi: isolate;">pyproject.toml</span> فيمكنك إضافة المعامل <span dir="ltr" style="unicode-bidi: isolate;">--format pyproject</span>. مثلًا:</p><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi init --format pyproject</code></pre>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">بيئتنا الافتراضية تفعيل</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">لأننا نريد متابعة إعداد البيئة، نحتاج إلى تفعيل البيئة الافتراضية. الأمر المستخدم هو <span dir="ltr" style="unicode-bidi: isolate;">pixi shell</span> لأن كلمة <span dir="ltr" style="unicode-bidi: isolate;">shell</span> تُستخدم للدلالة على واجهة سطر الأوامر لنظام التشغيل.</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi shell</code></pre>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><span dir="ltr" style="unicode-bidi: isolate;">Pixi</span> باستخدام برمجية اعتمادات إضافة</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">لنرَ كيف يمكننا استخدام <span dir="ltr" style="unicode-bidi: isolate;">pixi</span> لإدارة الاعتمادات البرمجية. سابقًا استخدمنا <span dir="ltr" style="unicode-bidi: isolate;">pip</span> لتثبيت حزم <span dir="ltr" style="unicode-bidi: isolate;">Python</span>. <span dir="ltr" style="unicode-bidi: isolate;">pixi</span> يمكنه إدارة أكثر من حزم <span dir="ltr" style="unicode-bidi: isolate;">Python</span>؛ بل يمكنه إدارة منصات برمجية كاملة مثل مُفسّر <span dir="ltr" style="unicode-bidi: isolate;">Python</span> نفسه.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">كمثال، لنخبر <span dir="ltr" style="unicode-bidi: isolate;">pixi</span> أننا نريد تضمين <span dir="ltr" style="unicode-bidi: isolate;">Python</span> في مشروعنا.</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add python</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">هذا لا يثبت مُفسّر <span dir="ltr" style="unicode-bidi: isolate;">Python</span> فقط؛ بل يخبر <span dir="ltr" style="unicode-bidi: isolate;">pixi</span> أن العناصر التي سنضيفها لاحقًا قد تكون وحدات <span dir="ltr" style="unicode-bidi: isolate;">Python</span> وأنه ينبغي البحث عنها في أماكن مثل <span dir="ltr" style="unicode-bidi: isolate;">PyPI</span>.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">كيف نثبت حزم <span dir="ltr" style="unicode-bidi: isolate;">Python</span>؟ بالأمر نفسه:</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code># Install the numpy package for Python
# pixi add numpy</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">سترى أشرطة تقدم بينما يحدد <span dir="ltr" style="unicode-bidi: isolate;">pixi</span> الحزمة المطلوبة ويحدد أحدث إصدار (لأننا لم نحدد إصدارًا) وينزلها ويثبت اعتماداتها ثم يثبت الحزمة. وهذا متوقع. لكن لننظر إلى ملف <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span> مجددًا: ستلاحظ تحديث قسم <span dir="ltr" style="unicode-bidi: isolate;">[dependencies]</span> مثلًا:</p><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>[dependencies]
# numpy = &quot;&gt;=2.3.5,&lt;3&quot;</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">قد تلاحظ أيضًا وجود ملف <span dir="ltr" style="unicode-bidi: isolate;">pixi.lock</span>. <a href="https://pixi.sh/latest/workspace/lockfile/" dir="ltr">يمكنك قراءة المزيد عنه هنا</a>، لكننا لن نناقشه لأننا لا نحتاج لفهم آليته لإدارة البيئة بشكل قابل لإعادة الإنتاج. كل المعلومات الأساسية التي نحتاجها موجودة في <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><hr></p><h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">الإصدارات تعارضات إدارة</h2><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">مدير الحزم الجيد يجب أن يتعامل مع التعارضات بين الحزم المختلفة وبين إصدارات اعتماداتها. في الوحدة 3 ناقشنا كيف قد يصبح مشروعنا معتمدًا على إصدار محدد من اعتماد برمجي. وعندما يعتمد مشروعنا على إصدارات محددة من حزمة أو أكثر، قد يتعارض ذلك مع متطلبات اعتماد آخر.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">لهذا المشروع نحتاج إلى التأكد من استخدام إصدار من <span dir="ltr" style="unicode-bidi: isolate;">numpy</span> <strong>أقل من</strong> الإصدار <span dir="ltr" style="unicode-bidi: isolate;">2.0</span>. أحدث إصدار قبل <span dir="ltr" style="unicode-bidi: isolate;">2.0</span> هو <span dir="ltr" style="unicode-bidi: isolate;">1.26.3</span>. هذا الإصدار لديه اعتمادات خاصة، وأهمها <span dir="ltr" style="unicode-bidi: isolate;">Python</span>، وقد صُمم ليعمل فقط مع إصدارات معينة من <span dir="ltr" style="unicode-bidi: isolate;">Python</span>. <strong>كيف نضمن تثبيت الإصدار الصحيح من</strong> <span dir="ltr" style="unicode-bidi: isolate;">numpy</span> <strong>وكذلك الإصدار الصحيح من</strong> <span dir="ltr" style="unicode-bidi: isolate;">Python</span>؟</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><span dir="ltr" style="unicode-bidi: isolate;">pixi</span> ومديرو حزم آخرون يتعاملون مع ذلك بسلاسة، لكن لضمان امتلاك <span dir="ltr" style="unicode-bidi: isolate;">pixi</span> لكل معلومات التعارضات المحتملة، <strong>نحتاج إلى تثبيت الحزم التي قد تتعارض في الوقت نفسه.</strong> في هذا المثال يعني ذلك تثبيت <span dir="ltr" style="unicode-bidi: isolate;">Python</span> وإصدار من <span dir="ltr" style="unicode-bidi: isolate;">numpy</span> أقل من <span dir="ltr" style="unicode-bidi: isolate;">2.0</span> في أمر واحد.</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add python &quot;numpy&lt;2&quot;</code></pre>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">👈 تلقائيًا البيئة إعداد</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>لكن انتظر! من المفترض أن يجعل</strong> <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span> <strong>إعداد البيئة سهلًا، فلماذا نثبت كل حزمة يدويًا؟</strong> نحن الآن نتعلم استخدام <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span> لأول مرة. ولكن إذا واجهت صعوبات أو أردت التخطي، فلاحظ أن هناك بالفعل ملف <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span> في هذا المستودع. يمكنك إعداد البيئة تلقائيًا اعتمادًا على ملف <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span> موجود مسبقًا عبر تنفيذ:</p><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code># Must be in the directory of the pixi.toml file
# pixi install</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">إذا اخترت استخدام <span dir="ltr" style="unicode-bidi: isolate;">pixi install</span> فمن الأفضل أن تقرأ بقية هذا الدرس لتفهم كيف يعمل <span dir="ltr" style="unicode-bidi: isolate;">Pixi</span>.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">المتبقية الاعتمادات تثبيت</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>لنثبت بقية الاعتمادات التي سنحتاجها لهذا الدرس.</strong></p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add earthaccess netcdf4 h5py matplotlib pyproj py4eos rasterio rioxarray shapely xarray notebook</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>ربما واجهت الخطأ التالي:</strong></p><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>Error:   × failed to solve requirements of environment...
#   ├─▶   × failed to solve the environment
#   │
#   ╰─▶ Cannot solve the request because of: No candidates were found for py4eos *.</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">يحدث هذا مع بعض الحزم المتاحة في <span dir="ltr" style="unicode-bidi: isolate;">PyPI</span> لكنها لم تُكتشف تلقائيًا—وغالبًا لأن <span dir="ltr" style="unicode-bidi: isolate;">conda</span> لا يفهرسها. لضمان أن <span dir="ltr" style="unicode-bidi: isolate;">pixi</span> يفحص <span dir="ltr" style="unicode-bidi: isolate;">PyPI</span> نضيف المعامل <span dir="ltr" style="unicode-bidi: isolate;">--pypi</span>:</p><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add --pypi py4eos</code></pre><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🚩 <span style="color:red">انتبه</span></h4><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>لأن الأمر الأصلي فشل، لم تُثبت أيٌّ من تلك الحزم الأخرى (غير</strong> <span dir="ltr" style="unicode-bidi: isolate;">py4eos</span><strong>).</strong> يجب أن نعيد تنفيذ <span dir="ltr" style="unicode-bidi: isolate;">pixi add</span> لتثبيت بقية الاعتمادات.</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add earthaccess netcdf4 h5py matplotlib pyproj rasterio rioxarray xarray shapely notebook</code></pre>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><hr></p><h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">بيئتك توثيق</h2><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">لقد أعددنا بيئة <span dir="ltr" style="unicode-bidi: isolate;">Python</span> وثبتنا جميع الاعتمادات اللازمة—ممتاز. لكن كيف نجعل ذلك أسهل لإعادة الإنتاج؟</p><ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">إذا احتجنا للبدء على جهاز آخر في المشروع نفسه، فسنضطر إلى تشغيل كل هذه الأوامر مرة أخرى.</li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">وإذا أراد شخص آخر إعادة إنتاج عملنا أو المساهمة فيه، فنريد أن نضمن أنه أعد جهازه بالطريقة نفسها.</li>
# </ul><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">ملف <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span> هو وصف كامل للبيئة التي أنشأناها. إذا فتحت الملف ستجد أنه يتحدث تلقائيًا بالاعتمادات التي ثبتناها. (المثال أدناه يوضح شكل قسم الاعتمادات):</p><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>[dependencies]
# python = &quot;&gt;=3.12.12,&lt;3.13&quot;
# numpy = &quot;&lt;2&quot;
# earthaccess = &quot;&gt;=0.15.1,&lt;0.16&quot;
# netcdf4 = &quot;&gt;=1.7.3,&lt;2&quot;
# h5py = &quot;&gt;=3.15.1,&lt;4&quot;
# matplotlib = &quot;&gt;=3.10.8,&lt;4&quot;
# pyproj = &quot;&gt;=3.7.2,&lt;4&quot;
# rasterio = &quot;&gt;=1.4.4,&lt;2&quot;
# rioxarray = &quot;&gt;=0.20.0,&lt;0.21&quot;
# xarray = &quot;&gt;=2025.12.0,&lt;2026&quot;
# notebook = &quot;&gt;=7.5.1,&lt;8&quot;
# shapely = &quot;&gt;=2.1.2,&lt;3&quot;
#
# [pypi-dependencies]
# py4eos = &quot;&gt;=0.5.0, &lt;0.6&quot;</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">لكن إذا كنت تعمل مع شخص لا يملك <span dir="ltr" style="unicode-bidi: isolate;">pixi</span> ولا يريد تثبيته، فلن يتمكن من استخدام <span dir="ltr" style="unicode-bidi: isolate;">pixi.toml</span>. وإذا كان يستخدم <span dir="ltr" style="unicode-bidi: isolate;">mamba</span> أو <span dir="ltr" style="unicode-bidi: isolate;">conda</span>، يمكنك إرسال ملف بيئة بصيغة <span dir="ltr" style="unicode-bidi: isolate;">conda</span> <span dir="ltr" style="unicode-bidi: isolate;">YAML</span>:</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi workspace export conda-environment</code></pre><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🍎 🐧 Mac OS/X و GNU/Linux</h4><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">على Mac OS/X وGNU/Linux يمكنك توجيه المخرجات إلى ملف:</p><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi workspace export conda-environment &gt; environment.yaml</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>يمكن الآن مشاركة ملف</strong> <span dir="ltr" style="unicode-bidi: isolate;">environment.yaml</span> <strong>مع أي شخص يريد إعادة إنشاء البيئة البرمجية.</strong></p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><hr></p><h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span> مع البدء</h2><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">حتى الآن لدينا مدير حزم <span dir="ltr" style="unicode-bidi: isolate;">pixi</span> يشبه في قدراته <span dir="ltr" style="unicode-bidi: isolate;">pip</span>. يمكننا الآن تثبيت حزم <span dir="ltr" style="unicode-bidi: isolate;">Python</span> وإنشاء لقطة من البيئة يمكن إعادة استخدامها ومشاركتها لضمان إعادة إنشاء البيئة الحاسوبية على جهاز آخر.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>لكن هذا نصف المشكلة فقط.</strong> ما زلنا بحاجة إلى طريقة سهلة لإعادة إنتاج <strong>سير العمل</strong> الذي سننشئه؛ أي طريقة لا تقتصر على تثبيت البيئة نفسها بل تشغيل البرامج <strong>بالطريقة نفسها</strong> التي شغّلناها بها.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">من الأدوات المبكرة لحل هذه المشكلة برنامج اسمه <span dir="ltr" style="unicode-bidi: isolate;">make</span>. كان يسمح بتشغيل سلسلة كاملة من مهام معقدة بأوامر بسيطة مثل <span dir="ltr" style="unicode-bidi: isolate;">make install</span> أو <span dir="ltr" style="unicode-bidi: isolate;">make results.csv</span>.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>في هذا الدرس سنستخدم أداة مشابهة لـ</strong> <span dir="ltr" style="unicode-bidi: isolate;">make</span> تُسمى <a href="https://snakemake.github.io/" dir="ltr">Snakemake</a>. ولتثبيت <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span> باستخدام <span dir="ltr" style="unicode-bidi: isolate;">pixi</span>:</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>pixi add --pypi Snakemake</code></pre>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <h3 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">قواعد إنشاء</h3><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>تقوم</strong> <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span> <strong>بأتمتة المهام، مثل سير العمل العلمي.</strong> كل مهمة تُعرَّف عبر <strong>قاعدة</strong> <span dir="ltr" style="unicode-bidi: isolate;">rule</span>، وغالبًا مع تحديد ملفات الإدخال وملفات الإخراج المطلوبة.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">كما في حلقات <span dir="ltr" style="unicode-bidi: isolate;">for</span> أو تعريف الدوال في <span dir="ltr" style="unicode-bidi: isolate;">Python</span>، تتضمن القواعد كلمة مفتاحية تليها نقطتان <span dir="ltr" style="unicode-bidi: isolate;">:</span> ثم كتلة شفرة. صياغة <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span> هي امتداد للغة <span dir="ltr" style="unicode-bidi: isolate;">Python</span>.</p><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">مثال بسيط جدًا قد يبدو كالتالي:</p><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code># Snakefile
# rule greeting:
#     shell: &quot;echo Hello, world!&quot;</code></pre><ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">بدلًا من <span dir="ltr" style="unicode-bidi: isolate;">def</span> أو <span dir="ltr" style="unicode-bidi: isolate;">for</span> نستخدم العبارة <span dir="ltr" style="unicode-bidi: isolate;">rule</span> لتسمية قاعدة جديدة.</li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">الكتلة المزاحة بعد النقطتين تحتوي كل ما يتعلق بهذه القاعدة.</li>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">خاصية <span dir="ltr" style="unicode-bidi: isolate;">shell</span> هي المكان الذي نكتب فيه الأمر الذي يجب تشغيله في سطر الأوامر لتنفيذ المهمة. في هذا المثال نريد تشغيل <span dir="ltr" style="unicode-bidi: isolate;">echo Hello, world!</span>.</li>
# </ul><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><strong>افتح محرر نصوص وضع القاعدة أعلاه في ملف نصي عادي باسم</strong> <span dir="ltr" style="unicode-bidi: isolate;">Snakefile</span> <strong>(بدون امتداد).</strong> ثم نفّذ القاعدة بالأمر:</p><h4 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">🪟 🍎 🐧 جميع أنظمة التشغيل</h4><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>snakemake greeting --cores=1 --quiet</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">ينبغي أن ترى مخرجات شبيهة بما يلي:</p><pre dir="ltr" style="unicode-bidi: isolate; text-align: left;"><code>Assuming unrestricted shared filesystem usage.
# host: Gullveig
# Building DAG of jobs...
# Using shell: /usr/bin/bash
# Select jobs to execute...
# Execute 1 jobs...
# Hello, world!
# Complete log(s): /usr/local/dev/demo-M5-project/.snakemake/log/2025-12-12T152205.384447.snakemake.log</code></pre><p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">قد يكون من الصعب ملاحظة ذلك وسط الأسطر الإضافية التي يطبعها <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span>، لكنه نفّذ المهمة فعلاً وكتب <span dir="ltr" style="unicode-bidi: isolate;">Hello, world!</span> على الشاشة.</p>
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;">سنواصل في الدروس التالية بناء قواعد أكثر واقعية تربط ملفات الإدخال والإخراج، وتسمح بإعادة تشغيل الأجزاء اللازمة فقط عند تغيّر البيانات أو الشيفرة.</p>
# </div>

# %% [markdown]
# <div dir="rtl" style="direction: rtl; unicode-bidi: isolate; text-align: right;">
# <p style="direction: rtl; unicode-bidi: plaintext; text-align: right;"><hr></p><h2 style="direction: rtl; unicode-bidi: plaintext; text-align: right;">موارد إضافية</h2><ul>
# <li style="direction: rtl; unicode-bidi: plaintext; text-align: right;">اقرأ عن كيف تُحدث أدوات سير العمل مثل <span dir="ltr" style="unicode-bidi: isolate;">Snakemake</span> ثورة في العلوم الحاسوبية (<a href="https://doi.org/10.1038/d41586-019-02619-z" dir="ltr">Nature</a>).</li>
# </ul>
# </div>
